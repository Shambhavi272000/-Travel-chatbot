# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer #to put similar words in same token 
from nltk import * 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#lemtizing each word

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())    #oipening intents file and feeding words to the lemmatizer

words=[]
classes = []
documents = []
ignore_letters = [',','?','.','!']   #letters we are going to ignore



#iterating over intent 

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_lists = nltk.word_tokenize(pattern)       #taking list of words for each pattern in intents dictionary from the json file and tokeizing which means breaking list of words into individual words.
        words.extend(word_lists)
        documents.append((word_lists, intent['tag']))#here we make sure that words only belonging to the particular tag/category is appended
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

#print(documents)

words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
word = sorted(set(words))  #removing duplicates


classes = sorted(set(classes))
pickle.dump(words, open('words.pkl','wb'))
pickle.dump(classes, open('classes.pkl','wb'))

#numerical values to words 0 and 1 if the word is present in the pattern

training =[]
output_empty= [0]* len(classes)

for document in documents:
    bag=[]
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
        
    output_row = list(output_empty)
    output_row[classes.index(document[1])]=1
    training.append([bag, output_row])

# %%
random.shuffle(training)
training = np.array(training)

train_x= list(training[:,0])
train_y = list(training[:,1])
# Out:
# <ipython-input-12-cd976dba1faf>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %%
model = Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation ='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation ='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax')) 

          
sgd = SGD(lr=0.01, decay = 1e-6,momentum = 0.9, nesterov = True )
model.compile(loss='CategoricalCrossentropy', optimizer= sgd, metrics=['accuracy'])
          

hist=model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5',hist)
print('done')
# Out:
# Epoch 1/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7920 - accuracy: 0.3235
# Epoch 2/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7065 - accuracy: 0.3529
# Epoch 3/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5579 - accuracy: 0.5000
# Epoch 4/200
# 7/7 [==============================] - 0s 853us/step - loss: 1.3967 - accuracy: 0.5000
# Epoch 5/200
# 7/7 [==============================] - 0s 996us/step - loss: 1.3910 - accuracy: 0.5000
# Epoch 6/200
# 7/7 [==============================] - 0s 995us/step - loss: 1.2459 - accuracy: 0.6176
# Epoch 7/200
# 7/7 [==============================] - 0s 995us/step - loss: 1.0838 - accuracy: 0.6471
# Epoch 8/200
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9162 - accuracy: 0.7059
# Epoch 9/200
# 7/7 [==============================] - 0s 995us/step - loss: 1.0584 - accuracy: 0.6471
# Epoch 10/200
# 7/7 [==============================] - 0s 996us/step - loss: 0.8307 - accuracy: 0.7059
# Epoch 11/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.8934 - accuracy: 0.6471
# Epoch 12/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.7215 - accuracy: 0.8235
# Epoch 13/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.7016 - accuracy: 0.7941
# Epoch 14/200
# 7/7 [==============================] - 0s 854us/step - loss: 0.6250 - accuracy: 0.7647
# Epoch 15/200
# 7/7 [==============================] - 0s 995us/step - loss: 0.7250 - accuracy: 0.7353
# Epoch 16/200
# 7/7 [==============================] - 0s 996us/step - loss: 0.5339 - accuracy: 0.8824
200
# 7/7 [==============================] - 0s 711us/step - loss: 0.2635 - accuracy: 0.8529
# Epoch 56/200
# 7/7 [==============================] - 0s 710us/step - loss: 0.1305 - accuracy: 0.9412
# Epoch 57/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1960 - accuracy: 0.9412
# Epoch 58/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.2642 - accuracy: 0.8824
# Epoch 59/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1929 - accuracy: 0.9412
# Epoch 60/200
# 7/7 [==============================] - 0s 710us/step - loss: 0.1412 - accuracy: 0.9412
# Epoch 61/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0942 - accuracy: 0.9706
# Epoch 62/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 63/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1185 - accuracy: 0.9412
# Epoch 64/200
# 7/7 [==============================] - 0s 569us/step - loss: 0.1485 - accuracy: 0.9412
# Epoch 65/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1518 - accuracy: 0.9118
# Epoch 66/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0840 - accuracy: 0.9706
# Epoch 67/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1042 - accuracy: 0.9706
# Epoch 68/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0565 - accuracy: 0.9706
# Epoch 69/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0853 - accuracy: 0.9706
# Epoch 70/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.1219 - accuracy: 0.9412
# Epoch 71/200
# 7/7 [==============================] - 0s 854us/step - loss: 0.1229 - accuracy: 0.9706
# Epoch 72/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1437 - accuracy: 0.9706
# Epoch 73/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0715 - accuracy: 0.9412
# Epoch 74/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.2125 - accuracy: 0.9118
# Epoch 75/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0755 - accuracy: 1.0000
# Epoch 76/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0717 - accuracy: 0.9706
# Epoch 77/200
# 7/7 [==============================] - 0s 852us/step - loss: 0.0987 - accuracy: 0.9706
# Epoch 78/200
# 7/7 [==============================] - 0s 712us/step - loss: 0.1185 - accuracy: 0.9412
# Epoch 79/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.1436 - accuracy: 0.9412
# Epoch 80/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1343 - accuracy: 0.9706
# Epoch 81/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1669 - accuracy: 0.9412
# Epoch 82/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1275 - accuracy: 0.9412
# Epoch 83/200
# 7/7 [==============================] - 0s 712us/step - loss: 0.0621 - accuracy: 1.0000
# Epoch 84/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0990 - accuracy: 0.9706
# Epoch 85/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.1134 - accuracy: 0.9118
# Epoch 86/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0676 - accuracy: 0.9412
# Epoch 87/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0756 - accuracy: 0.9706
# Epoch 88/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0944 - accuracy: 0.9706
# Epoch 89/200
# 7/7 [==============================] - 0s 710us/step - loss: 0.0948 - accuracy: 0.9706
# Epoch 90/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0710 - accuracy: 0.9706
# Epoch 91/200
# 7/7 [==============================] - 0s 813us/step - loss: 0.1430 - accuracy: 0.9412
# Epoch 92/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1125 - accuracy: 0.9706
# Epoch 93/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0842 - accuracy: 0.9706
# Epoch 94/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0903 - accuracy: 0.9706
# Epoch 95/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1682 - accuracy: 0.9412
# Epoch 96/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1630 - accuracy: 0.9412
# Epoch 97/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 98/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1539 - accuracy: 0.9118
# Epoch 99/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0926 - accuracy: 0.9706
# Epoch 100/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0636 - accuracy: 0.9706
# Epoch 101/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0956 - accuracy: 0.9118
# Epoch 102/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0826 - accuracy: 0.9706
# Epoch 103/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0604 - accuracy: 0.9706
# Epoch 104/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0820 - accuracy: 1.0000
# Epoch 105/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0877 - accuracy: 0.9706
# Epoch 106/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0730 - accuracy: 0.9706
# Epoch 107/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1119 - accuracy: 0.9706
# Epoch 108/200
# 7/7 [==============================] - 0s 642us/step - loss: 0.0557 - accuracy: 1.0000
# Epoch 109/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0716 - accuracy: 0.9706
# Epoch 110/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0967 - accuracy: 0.9412
# Epoch 111/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0528 - accuracy: 0.9706
# Epoch 112/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1349 - accuracy: 0.9412
# Epoch 113/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 114/200
# 7/7 [==============================] - 0s 854us/step - loss: 0.0366 - accuracy: 0.9706
# Epoch 115/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0616 - accuracy: 1.0000
# Epoch 116/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0694 - accuracy: 0.9706
# Epoch 117/200
# 7/7 [==============================] - 0s 854us/step - loss: 0.1154 - accuracy: 0.9412
# Epoch 118/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.1357 - accuracy: 0.9706
# Epoch 119/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0977 - accuracy: 0.9412
# Epoch 120/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0768 - accuracy: 1.0000
# Epoch 121/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 122/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0878 - accuracy: 1.0000
# Epoch 123/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0687 - accuracy: 0.9706
# Epoch 124/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1513 - accuracy: 0.8824
# Epoch 125/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0863 - accuracy: 0.9706
# Epoch 126/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 127/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0818 - accuracy: 0.9706
# Epoch 128/200
# 7/7 [==============================] - 0s 710us/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 129/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0461 - accuracy: 1.0000
# Epoch 130/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0806 - accuracy: 0.9706
# Epoch 131/200
# 7/7 [==============================] - 0s 664us/step - loss: 0.1299 - accuracy: 0.9412
# Epoch 132/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0406 - accuracy: 0.9706
# Epoch 133/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 134/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0972 - accuracy: 0.9706
# Epoch 135/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0509 - accuracy: 0.9706
# Epoch 136/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0691 - accuracy: 0.9706
# Epoch 137/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0411 - accuracy: 0.9706
# Epoch 138/200
# 7/7 [==============================] - 0s 569us/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 139/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 140/200
# 7/7 [==============================] - 0s 837us/step - loss: 0.0774 - accuracy: 0.9706
# Epoch 141/200
# 7/7 [==============================] - 0s 569us/step - loss: 0.1443 - accuracy: 0.9412
# Epoch 142/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0747 - accuracy: 0.9706
# Epoch 143/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0825 - accuracy: 0.9706
# Epoch 144/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0870 - accuracy: 0.9706
# Epoch 145/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1004 - accuracy: 0.9412
# Epoch 146/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 147/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 148/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0513 - accuracy: 0.9706
# Epoch 149/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0938 - accuracy: 0.9412
# Epoch 150/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0727 - accuracy: 0.9706
# Epoch 151/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0638 - accuracy: 0.9706
# Epoch 152/200
# 7/7 [==============================] - 0s 712us/step - loss: 0.0521 - accuracy: 0.9706
# Epoch 153/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 154/200
# 7/7 [==============================] - 0s 569us/step - loss: 0.1401 - accuracy: 0.9412
# Epoch 155/200
# 7/7 [==============================] - 0s 805us/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 156/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 157/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0470 - accuracy: 0.9706
# Epoch 158/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0649 - accuracy: 0.9412
# Epoch 159/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0316 - accuracy: 0.9706
# Epoch 160/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0898 - accuracy: 0.9412
# Epoch 161/200
# 7/7 [==============================] - 0s 712us/step - loss: 0.1308 - accuracy: 0.9412
# Epoch 162/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 163/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 164/200
# 7/7 [==============================] - 0s 648us/step - loss: 0.1438 - accuracy: 0.9706
# Epoch 165/200
# 7/7 [==============================] - 0s 570us/step - loss: 0.0620 - accuracy: 0.9706
# Epoch 166/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1046 - accuracy: 0.9706
# Epoch 167/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1692 - accuracy: 0.9118
# Epoch 168/200
# 7/7 [==============================] - 0s 569us/step - loss: 0.0566 - accuracy: 1.0000
# Epoch 169/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0923 - accuracy: 0.9706
# Epoch 170/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0683 - accuracy: 0.9706
# Epoch 171/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0620 - accuracy: 0.9706
# Epoch 172/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0943 - accuracy: 0.9706
# Epoch 173/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1006 - accuracy: 0.9706
# Epoch 174/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0429 - accuracy: 0.9706
# Epoch 175/200
# 7/7 [==============================] - 0s 569us/step - loss: 0.1069 - accuracy: 0.9706
# Epoch 176/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0421 - accuracy: 0.9706
# Epoch 177/200
# 7/7 [==============================] - 0s 569us/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 178/200
# 7/7 [==============================] - 0s 569us/step - loss: 0.0574 - accuracy: 0.9706
# Epoch 179/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0961 - accuracy: 0.9706
# Epoch 180/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0450 - accuracy: 0.9706
# Epoch 181/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1055 - accuracy: 0.9412
# Epoch 182/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0825 - accuracy: 0.9706
# Epoch 183/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0555 - accuracy: 0.9706
# Epoch 184/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 185/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0347 - accuracy: 0.9706
# Epoch 186/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1803 - accuracy: 0.9118
# Epoch 187/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0743 - accuracy: 0.9706
# Epoch 188/200
# 7/7 [==============================] - 0s 661us/step - loss: 0.0800 - accuracy: 0.9706
# Epoch 189/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0867 - accuracy: 0.9706
# Epoch 190/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0719 - accuracy: 0.9412
# Epoch 191/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.0699 - accuracy: 0.9706
# Epoch 192/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0924 - accuracy: 0.9412
# Epoch 193/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0675 - accuracy: 0.9412
# Epoch 194/200
# 7/7 [==============================] - 0s 853us/step - loss: 0.1057 - accuracy: 0.9412
# Epoch 195/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 196/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 197/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0600 - accuracy: 0.9706
# Epoch 198/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0420 - accuracy: 0.9706
# Epoch 199/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.1276 - accuracy: 0.9412
# Epoch 200/200
# 7/7 [==============================] - 0s 711us/step - loss: 0.0734 - accuracy: 0.9706
# done
